# %%
import pandas as pd

data = pd.read_csv('dataset_export.csv')
data
# Out:
#          annee                        profession_sante  region  \
# 0         2013      Ensemble des médecins généralistes      75
# 1         2013      Ensemble des médecins généralistes      75
# 2         2013      Ensemble des médecins généralistes      75
# 3         2013      Ensemble des médecins généralistes      75
# 4         2013      Ensemble des médecins généralistes      75
# ...        ...                                     ...     ...
# 1182715   2022  Gynécologues médicaux et obstétriciens      24
# 1182716   2022  Gynécologues médicaux et obstétriciens      24
# 1182717   2022  Gynécologues médicaux et obstétriciens      24
# 1182718   2022  Gynécologues médicaux et obstétriciens      24
# 1182719   2022  Gynécologues médicaux et obstétriciens      24
#
#               libelle_region departement libelle_departement  \
# 0         Nouvelle-Aquitaine          16            Charente
# 1         Nouvelle-Aquitaine          16            Charente
# ...
